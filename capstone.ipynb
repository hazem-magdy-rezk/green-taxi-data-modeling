# %%
import pandas as pd

# %%
df=pd.read_json('c:\\Users\hazem.hazem/Desktop/capstone/json/*.json')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\HAZEM~1.HAZ\AppData\Local\Temp/ipykernel_6316/2872864593.py in <module>
# ----> 1 df=pd.read_json('c:\\Users\hazem.hazem/Desktop/capstone/json/*.json')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 0           1       2.0  01/01/2020 12:45:58 AM  01/01/2020 12:56:39 AM
# 1           2       2.0  01/01/2020 12:41:38 AM  01/01/2020 12:52:49 AM
# 2           3       1.0  01/01/2020 12:52:46 AM  01/01/2020 01:14:21 AM
# 3           4       1.0  01/01/2020 12:19:57 AM  01/01/2020 12:30:56 AM
# 4           5       1.0  01/01/2020 12:52:33 AM  01/01/2020 01:09:54 AM
#
#   store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  passenger_count  \
# 0                  N         5.0            66            65              2.0
# 1                  N         1.0           181           228              1.0
# 2                  N         1.0           129           263              2.0
# 3                  N         1.0           210           150              1.0
# 4                  N         1.0            35            39              1.0
#
#    trip_distance  ...  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
# Out:
#    VendorID    lpep_pickup_datetime   lpep_dropoff_datetime  \
# 1       2.0  01/01/2020 12:45:58 AM  01/01/2020 12:56:39 AM
# 2       2.0  01/01/2020 12:41:38 AM  01/01/2020 12:52:49 AM
# 3       1.0  01/01/2020 12:52:46 AM  01/01/2020 01:14:21 AM
# 4       1.0  01/01/2020 12:19:57 AM  01/01/2020 12:30:56 AM
# 5       1.0  01/01/2020 12:52:33 AM  01/01/2020 01:09:54 AM
#
#   store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  passenger_count  \
# 1                  N         5.0            66            65              2.0
# 2                  N         1.0           181           228              1.0
# 3                  N         1.0           129           263              2.0
# 4                  N         1.0           210           150              1.0
# 5                  N         1.0            35            39              1.0
#
#    trip_distance  fare_amount  ...  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df1=df[df['months']==1]
df2=df[df['months']==2]
df3=df[df['months']==3]
df4=df[df['months']==4]
df5=df[df['months']==5]
df6=df[df['months']==6]
df7=df[df['months']==7]
df8=df[df['months']==8]
df9=df[df['months']==9]
df10=df[df['months']==10]
df11=df[df['months']==11]
df12=df[df['months']==12]

# %%
pd.read_parquet('taxi_data.parquet')
